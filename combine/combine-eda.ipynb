# %% [markdown]
# # SEARCH FOR A QUESTION

# %%
import pandas as pd
import plotly.express as px
# import matplotlib.potly as plt
# %matplotlib inline

# %% [markdown]
# ##### **DATA FILE**
#
# CSV file contains data about NFL players and draft.
#
# Problems:
# * When player's name contains `Jr.` part row in file has too many colons - It was necessary to remove colons before every ` Jr.` string.

# %%
filepath = '../data/combine.csv'
df = pd.read_csv(filepath)
df
# Out:
#       year            name firstname   lastname position  heightfeet  \
# 0     2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1     2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2     2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3     2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4     2015    Mario Alford     Mario     Alford       WR           5
# ...    ...             ...       ...        ...      ...         ...
# 4942  1999    Daren Yancey     Daren     Yancey       DT           6
# 4943  1999     Craig Yeast     Craig      Yeast       WR           5
# 4944  1999      Ryan Young      Ryan      Young       OT           6
# 4945  1999   Peppi Zellner     Peppi    Zellner       DE           6
# 4946  1999    Amos Zereoue      Amos    Zereoue       RB           5
#
#       heightinches  heightinchestotal  weight  arms  ...  vertical  broad  \
# 0              9.0               69.0     205   0.0  ...      42.5    130
# 1              0.0               72.0     198   0.0  ...       0.0      0
# 2              0.0               72.0     221   0.0  ...      39.0    121
# 3              1.0               73.0     227   0.0  ...      36.0    121
# 4              8.0               68.0     180   0.0  ...      34.0    121
# ...            ...                ...     ...   ...  ...       ...    ...
# 4942           6.0               78.0     303   0.0  ...      26.5     97
# 4943           8.0               68.0     164   0.0  ...      32.5    112
# 4944           6.0               78.0     335   0.0  ...       0.0      0
# 4945           5.0               77.0     246   0.0  ...      35.5    122
# 4946           8.0               68.0     203   0.0  ...       0.0      0
#
#       bench  round            college     pick  pickround  picktotal  \
# 0        24      0           Nebraska      NaN          0          0
# 1        12      0                USC      NaN          0          0
# 2        19      0          Boise St.      NaN          0          0
# 3        24      0                LSU      NaN          0          0
# 4        13      0      West Virginia      NaN          0          0
# ...     ...    ...                ...      ...        ...        ...
# 4942      0      6      Brigham Young  19(188)         19        188
# 4943      0      4           Kentucky    3(98)          3         98
# 4944     20      7       Kansas State  17(223)         17        223
# 4945     20      4  Fort Valley State  37(132)         37        132
# 4946      0      3      West Virginia   34(95)         34         95
#
#       wonderlic  nflgrade
# 0             0       5.9
# 1             0       5.6
# 2             0       6.0
# 3             0       5.4
# 4             0       5.3
# ...         ...       ...
# 4942          0       0.0
# 4943          0       0.0
# 4944          0       0.0
# 4945          0       0.0
# 4946          0       0.0
#
# [4947 rows x 26 columns]

# %% [markdown]
# ## NFL Grade

# %%
px.box(df, x='year', y='nflgrade', title='NFL Grade distribution by Year')

# %%
df_grade = df[df.nflgrade > 0]
df_grade.shape
# Out:
# (646, 26)

# %% [markdown]
# ##### NFL Grade distribution
# NFL Grades contain only players drafted since 2014 - It is **646** non-zero records.

# %% [markdown]
# ## DRAFT/PICKS

# %%
df_pick = df[(~df.pick.isna()) & (df.picktotal > 0)]
df_pick.shape
# Out:
# (3044, 26)

# %%
px.box(df, x='year', y='pickround', title='NFL pickround distribution by Year')

# %%
px.box(df_pick, x='year', y='pickround', title='NFL pickround distribution by Year')

# %% [markdown]
# ##### NFL draft distribution
#
# Only the latest (2015) year has not saved picks. There is **3044** records with filled pcikround column.

# %% [markdown]
# ## CHECK DATA CLEANLINESS

# %%
df.columns
# Out:
# Index(['year', 'name', 'firstname', 'lastname', 'position', 'heightfeet',
#        'heightinches', 'heightinchestotal', 'weight', 'arms', 'hands',
#        'fortyyd', 'twentyyd', 'tenyd', 'twentyss', 'threecone', 'vertical',
#        'broad', 'bench', 'round', 'college', 'pick', 'pickround', 'picktotal',
#        'wonderlic', 'nflgrade'],
#       dtype='object')

# %%
columns = [
    'position', 'heightinchestotal', 'weight', 'arms', 'hands',
    'fortyyd', 'twentyyd', 'tenyd', 'twentyss', 'threecone', 'vertical',
    'broad', 'bench', 'round', 'college', 'pickround', 'picktotal'
]
_ = df_pick[columns].hist(figsize=(20, 10), bins=30)

# %%
df_pick[(df_pick.position.isna()) | (df_pick.college.isna())].shape
df_pick.dropna(subset=['position', 'college'], inplace=True)
# Out:
# /tmp/ipykernel_7842/1556135914.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
valuable_col = []
for col in columns:
    if df[col].dtype != 'object':
        percent_more_zero = df_pick[df_pick[col] > 0].shape[0]/df_pick.shape[0]
        if percent_more_zero > 0.7:
            valuable_col.append(col)
    else:
        valuable_col.append(col)

# %%
corr = df_pick[valuable_col].corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /tmp/ipykernel_7842/202832445.py:2: FutureWarning:
#
# this method is deprecated in favour of `Styler.format(precision=..)`
# <style type="text/css">
# #T_c6a65_row0_col0, #T_c6a65_row1_col1, #T_c6a65_row2_col2, #T_c6a65_row3_col3, #T_c6a65_row4_col4, #T_c6a65_row5_col5, #T_c6a65_row6_col6, #T_c6a65_row7_col7, #T_c6a65_row8_col8, #T_c6a65_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c6a65_row0_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_c6a65_row0_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_c6a65_row0_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_c6a65_row0_col4, #T_c6a65_row8_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_c6a65_row0_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c6a65_row0_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_c6a65_row0_col7, #T_c6a65_row0_col8, #T_c6a65_row0_col9, #T_c6a65_row1_col4, #T_c6a65_row1_col5, #T_c6a65_row4_col0, #T_c6a65_row4_col1, #T_c6a65_row4_col6, #T_c6a65_row7_col2, #T_c6a65_row8_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c6a65_row1_col0 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_c6a65_row1_col2, #T_c6a65_row2_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_c6a65_row1_col3, #T_c6a65_row7_col0, #T_c6a65_row9_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c6a65_row1_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_c6a65_row1_col7, #T_c6a65_row4_col7, #T_c6a65_row8_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c6a65_row1_col8, #T_c6a65_row1_col9, #T_c6a65_row4_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c6a65_row2_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_c6a65_row2_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c6a65_row2_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_c6a65_row2_col5, #T_c6a65_row8_col9, #T_c6a65_row9_col8 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_c6a65_row2_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_c6a65_row2_col7, #T_c6a65_row5_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_c6a65_row2_col8, #T_c6a65_row2_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_c6a65_row3_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c6a65_row3_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_c6a65_row3_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_c6a65_row3_col4 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_c6a65_row3_col5 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_c6a65_row3_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_c6a65_row3_col7, #T_c6a65_row3_col9 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c6a65_row3_col8, #T_c6a65_row6_col8, #T_c6a65_row7_col3, #T_c6a65_row9_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c6a65_row4_col2, #T_c6a65_row7_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_c6a65_row4_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c6a65_row4_col5 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_c6a65_row4_col8, #T_c6a65_row5_col7, #T_c6a65_row5_col9, #T_c6a65_row6_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_c6a65_row5_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c6a65_row5_col2, #T_c6a65_row7_col1, #T_c6a65_row9_col1, #T_c6a65_row9_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_c6a65_row5_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_c6a65_row5_col4 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_c6a65_row5_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c6a65_row5_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c6a65_row6_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_c6a65_row6_col1 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_c6a65_row6_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c6a65_row6_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c6a65_row6_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_c6a65_row6_col7, #T_c6a65_row6_col9 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c6a65_row7_col4, #T_c6a65_row8_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_c6a65_row7_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_c6a65_row7_col6, #T_c6a65_row9_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c6a65_row7_col9, #T_c6a65_row9_col7 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_c6a65_row8_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c6a65_row8_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_c6a65_row8_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_c6a65_row8_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c6a65_row9_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c6a65_row9_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c6a65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6a65_level0_col0" class="col_heading level0 col0" >heightinchestotal</th>
#       <th id="T_c6a65_level0_col1" class="col_heading level0 col1" >weight</th>
#       <th id="T_c6a65_level0_col2" class="col_heading level0 col2" >fortyyd</th>
#       <th id="T_c6a65_level0_col3" class="col_heading level0 col3" >twentyss</th>
#       <th id="T_c6a65_level0_col4" class="col_heading level0 col4" >vertical</th>
#       <th id="T_c6a65_level0_col5" class="col_heading level0 col5" >broad</th>
#       <th id="T_c6a65_level0_col6" class="col_heading level0 col6" >bench</th>
#       <th id="T_c6a65_level0_col7" class="col_heading level0 col7" >round</th>
#       <th id="T_c6a65_level0_col8" class="col_heading level0 col8" >pickround</th>
#       <th id="T_c6a65_level0_col9" class="col_heading level0 col9" >picktotal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6a65_level0_row0" class="row_heading level0 row0" >heightinchestotal</th>
#       <td id="T_c6a65_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_c6a65_row0_col1" class="data row0 col1" >0.72</td>
#       <td id="T_c6a65_row0_col2" class="data row0 col2" >0.22</td>
#       <td id="T_c6a65_row0_col3" class="data row0 col3" >0.12</td>
#       <td id="T_c6a65_row0_col4" class="data row0 col4" >-0.16</td>
#       <td id="T_c6a65_row0_col5" class="data row0 col5" >-0.10</td>
#       <td id="T_c6a65_row0_col6" class="data row0 col6" >0.20</td>
#       <td id="T_c6a65_row0_col7" class="data row0 col7" >-0.04</td>
#       <td id="T_c6a65_row0_col8" class="data row0 col8" >-0.03</td>
#       <td id="T_c6a65_row0_col9" class="data row0 col9" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_c6a65_level0_row1" class="row_heading level0 row1" >weight</th>
#       <td id="T_c6a65_row1_col0" class="data row1 col0" >0.72</td>
#       <td id="T_c6a65_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_c6a65_row1_col2" class="data row1 col2" >0.28</td>
#       <td id="T_c6a65_row1_col3" class="data row1 col3" >0.11</td>
#       <td id="T_c6a65_row1_col4" class="data row1 col4" >-0.27</td>
#       <td id="T_c6a65_row1_col5" class="data row1 col5" >-0.19</td>
#       <td id="T_c6a65_row1_col6" class="data row1 col6" >0.45</td>
#       <td id="T_c6a65_row1_col7" class="data row1 col7" >-0.02</td>
#       <td id="T_c6a65_row1_col8" class="data row1 col8" >-0.01</td>
#       <td id="T_c6a65_row1_col9" class="data row1 col9" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_c6a65_level0_row2" class="row_heading level0 row2" >fortyyd</th>
#       <td id="T_c6a65_row2_col0" class="data row2 col0" >0.22</td>
#       <td id="T_c6a65_row2_col1" class="data row2 col1" >0.28</td>
#       <td id="T_c6a65_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_c6a65_row2_col3" class="data row2 col3" >0.27</td>
#       <td id="T_c6a65_row2_col4" class="data row2 col4" >0.21</td>
#       <td id="T_c6a65_row2_col5" class="data row2 col5" >0.21</td>
#       <td id="T_c6a65_row2_col6" class="data row2 col6" >0.15</td>
#       <td id="T_c6a65_row2_col7" class="data row2 col7" >0.02</td>
#       <td id="T_c6a65_row2_col8" class="data row2 col8" >0.03</td>
#       <td id="T_c6a65_row2_col9

# %% [markdown]
# #### CHOSEN COLUMNS
#
# * position
# * college
# * heightinchestotal
# * weight
# * fortyyd (40 yard dash)
# * twentyss (20 yard shuttle)
# * vertical (jump)
# * broad	(jump)
# * bench (press)

# %% [markdown]
# #### SEARCHING RESULT
#
# * picktotal
# * pickround

# %%
def count_zeros(record):
    return sum(record == 0)

df_pick = df_pick[valuable_col]
df_pick['zeros'] = df_pick[valuable_col].apply(count_zeros, axis=1)
df_pick.zeros.value_counts()
# Out:
# 0    1673
# 1     813
# 3     254
# 2     200
# 4      72
# 5      31
# Name: zeros, dtype: int64

# %%
method = 'drop' # 'drop' or 'fill'

if method == 'drop':
    df_pick.drop(df_pick[df_pick.zeros > 0].index, axis=0, inplace=True)
else:
    df_pick.drop(df_pick[df_pick.zeros > 3].index, axis=0, inplace=True)
df_pick.zeros.value_counts()
# Out:
# 0    1673
# Name: zeros, dtype: int64

# %%
def get_sample(df, col):
    df_sample = df[df[col] > 0]
    sample = df_sample.sample(n=1)[col].item()
    return sample
    
for col in valuable_col:
    if df_pick[col].dtype != 'object':
        for record in df_pick.iterrows():
            if record[1][col] == 0:
                df_pick.loc[record[0], col] = get_sample(df, col)
                        
_ = df_pick.hist(figsize=(20, 10), bins=30)

# %% [markdown]
# #### FILLING ZEROS
#
# zeros were replaced by random sample from the same column except zeros (distribution of the column stays the same except zero values).
#
# In other approach records with zeros have been deleted.

# %%
df_pick.drop(columns=['zeros', 'round'], inplace=True)
df_pick.columns
# Out:
# Index(['position', 'heightinchestotal', 'weight', 'fortyyd', 'twentyss',
#        'vertical', 'broad', 'bench', 'college', 'pickround', 'picktotal'],
#       dtype='object')

# %%
df_pick.to_csv(f'../data/combine_{method}.csv')

# %% [markdown]
# # **QUESTION**: WHEN WILL PLAYER BE PICKED?
